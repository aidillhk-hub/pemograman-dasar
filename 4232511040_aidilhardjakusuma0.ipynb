# %% [markdown]
# <a href="https://colab.research.google.com/github/aidillhk-hub/pemograman-dasar/blob/main/4232511040_aidilhardjakusuma0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# biodata saya

nama = "Aidil hardja kusuma"
umur = 20
jurusan = "RPE"
semester = 3
matakuliah = 'Pemograman dasar'
status_lulus = False

print (nama)
print (umur)
print (jurusan)
print (semester)
print (matakuliah)
print (status_lulus)
# Out:
# Aidil hardja kusuma
# 20
# RPE
# 3
# Pemograman dasar
# False
