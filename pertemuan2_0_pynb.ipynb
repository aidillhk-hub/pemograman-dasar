# %% [markdown]
# <a href="https://colab.research.google.com/github/aidillhk-hub/pemograman-dasar/blob/main/pertemuan2_0_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
voltage_volt = 18
current_ampere = 6
cell_type = "Monocrystalline"

print(f"Tegangan: {voltage_volt} volt")
print(f"Arus: {current_ampere} ampere")
print(f"Jenis Sel: {cell_type}")
# Out:
# Tegangan: 18 volt
# Arus: 6 ampere
# Jenis Sel: Monocrystalline

# %%
resistor_value_ohms = 1000 # int
capacitor_value_uf = 0.1   # float
is_led_working = True      # bool
component_name = "Transistor BC547" # str

print(f"Resistor Value: {resistor_value_ohms} ohms, Type: {type(resistor_value_ohms)}")
print(f"Capacitor Value: {capacitor_value_uf} uF, Type: {type(capacitor_value_uf)}")
print(f"Is LED Working: {is_led_working}, Type: {type(is_led_working)}")
print(f"Component Name: {component_name}, Type: {type(component_name)}")
# Out:
# Resistor Value: 1000 ohms, Type: <class 'int'>
# Capacitor Value: 0.1 uF, Type: <class 'float'>
# Is LED Working: True, Type: <class 'bool'>
# Component Name: Transistor BC547, Type: <class 'str'>

# %%
unit_name = "PLTS Nunukan" # str
num_panels = 240           # int
output_voltage = 48.5      # float
is_operational = True      # bool

print(f"Nama Unit: {unit_name}, Tipe: {type(unit_name)}")
print(f"Jumlah Panel: {num_panels}, Tipe: {type(num_panels)}")
print(f"Tegangan Keluaran: {output_voltage}, Tipe: {type(output_voltage)}")
print(f"Sedang Beroperasi: {is_operational}, Tipe: {type(is_operational)}")
# Out:
# Nama Unit: PLTS Nunukan, Tipe: <class 'str'>
# Jumlah Panel: 240, Tipe: <class 'int'>
# Tegangan Keluaran: 48.5, Tipe: <class 'float'>
# Sedang Beroperasi: True, Tipe: <class 'bool'>

# %%
tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]

# (a) Cetak pembacaan pertama dan terakhir memakai indeks
print(f"Pembacaan pertama: {tegangan_harian[0]}")
print(f"Pembacaan terakhir: {tegangan_harian[-1]}")

# (b) Tambahkan satu pembacaan baru 222.0 dengan append()
tegangan_harian.append(222.0)
print(f"Daftar tegangan setelah ditambah: {tegangan_harian}")

# (c) Cetak jumlah total data dengan len()
print(f"Jumlah total data: {len(tegangan_harian)}")
# Out:
# Pembacaan pertama: 217.5
# Pembacaan terakhir: 216.9
# Daftar tegangan setelah ditambah: [217.5, 219.0, 220.3, 218.7, 221.1, 216.9, 222.0]
# Jumlah total data: 7

# %%
motor_spec = {
    "nama": "Motor Induksi",
    "daya_kW": 1.5,
    "tegangan_V": 380,
    "rpm": 1450
}

# Cetak salah satu nilai lewat key-nya
print(f"Daya motor: {motor_spec['daya_kW']} kW")

# Ubah nilai rpm
motor_spec['rpm'] = 1500

# Cetak ulang seluruh dictionary
print("Spesifikasi motor setelah perubahan:")
print(motor_spec)
# Out:
# Daya motor: 1.5 kW
# Spesifikasi motor setelah perubahan:
# {'nama': 'Motor Induksi', 'daya_kW': 1.5, 'tegangan_V': 380, 'rpm': 1500}
